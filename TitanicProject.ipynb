# %% [markdown]
# # Yonela Mangxaba Titanic Dataset

# %% [markdown]
# ## Introduction

# %% [markdown]
# The purpose of this project is to perform data analysis on either the titanic or baseball datasets, it is to see whether we are capable of analysing the data and being able to form questions just by looking at the data. It is to whether we capable of answering the questions using the data provided. The dataset has information on the passengers of the titanic.
# I used the python notebook also numpy, pandas, matplotlib.pyplot and seaborn python modules in order to analysis the data

# %% [markdown]
#  ## Questions
# 1.	How many data records where available about the passengers?
# 2.	How many female survivors?
# 3.	How many male survivors?
# 4.	How many female deaths?
# 5.	How many male deaths?
# 6.	How many children survived?
# 7.	How many children did not survive?
# 8.	How many records are missing the age data?

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
titanic_data = pd.read_csv('titanic_data.csv')

# %%
len(titanic_data)
# Out:
# 891

# %%
df = pd.read_csv('titanic_data.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 861      male
# 862    female
# 863    female
# 864      male
# 865    female
# 866    female
# 867      male
# 868      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 878      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# ...

# %%
df.Age.hist()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_data_duplicates = titanic_data.duplicated()
print (titanic_data_duplicates.sum())
# Out:
# 0

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
survivors = df[df['Survived'] == 1]
non_survivors = df[df['Survived'] == 0]

# %%
# Prints survivors/deaths by number
first_class_survivors = len(survivors[survivors['Pclass'] == 1])
second_class_survivors = len(survivors[survivors['Pclass'] == 2])
third_class_survivors = len(survivors[survivors['Pclass'] == 3])

first_class_deaths = len(non_survivors[non_survivors['Pclass'] == 1])
second_class_deaths = len(non_survivors[non_survivors['Pclass'] == 2])
third_class_deaths = len(non_survivors[non_survivors['Pclass'] == 3])

males = len(df[df['Sex'] == 'male'])
females = len(df[df['Sex'] == 'female'])

male_survivors = len(survivors[survivors['Sex'] == 'male'])
female_survivors = len(survivors[survivors['Sex'] == 'female'])
male_non_survivors = len(non_survivors[non_survivors['Sex'] == 'male'])
female_non_survivors = len(non_survivors[non_survivors['Sex'] == 'female'])

survivor_ages = df[df['Survived'] == 1]
non_survivor_ages = df[df['Survived'] == 0]


print ('First class survivors: ' + str (first_class_survivors)) 
print ('First class deaths: ' + str(first_class_deaths))
print ('Second class survivors: ' + str(second_class_survivors))
print ('Second class deaths: ' + str(second_class_deaths))
print ('Third class survivors: ' + str(third_class_survivors))
print ('Third class deaths: ' + str(third_class_deaths))
# Out:
# First class survivors: 136
# First class deaths: 80
# Second class survivors: 87
# Second class deaths: 97
# Third class survivors: 119
# Third class deaths: 372

# %%
def plot_series(data, kind_str):
    data.plot(kind=kind_str)

# %%
plot_series(pd.Series([male_survivors, female_survivors], index=['Male Survivors', 'Female Survivors'], name='Survivors'), 'pie')
print ('Male Survivors: ' + str(male_survivors))
print ('Female Survivors: ' + str(female_survivors))
# Out:
# Male Survivors: 109
# Female Survivors: 233

# %%
plot_series(pd.Series([male_non_survivors, female_non_survivors], index=['Male Non Survivors', 'Female Non Survivors'], name='Non Survivors'), 'pie')
print ('Male  Non survivors: ' + str(male_non_survivors))
print ('Female Non Survivors: ' + str(female_non_survivors))
# Out:
# Male  Non survivors: 468
# Female Non Survivors: 81

# %%
titanic_data.loc[
     (titanic_data['Age'] < 18 )]


g = sns.factorplot('Survived', data=titanic_data, kind='count', size=7, aspect=.8)
(g.set_axis_labels('Survivors', 'No. of Passengers')
    .set_xticklabels(['Non Survivors', 'Survivors'])
)

titles = ['Children']
for ax, title in zip(g.axes.flat, titles):
    ax.set_title(title)

# %%
titanic_data[titanic_data['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass   Name     Sex    Age  SibSp  Parch  \
# 7              8         0       3  Child    male   2.00      3      1
# 9             10         1       2  Child  female  14.00      1      0
# 10            11         1       3  Child  female   4.00      1      1
# 14            15         0       3  Child  female  14.00      0      0
# 16            17         0       3  Child    male   2.00      4      1
# 22            23         1       3  Child  female  15.00      0      0
# 24            25         0       3  Child  female   8.00      3      1
# 39            40         1       3  Child  female  14.00      1      0
# 43            44         1       2  Child  female   3.00      1      2
# 50            51         0       3  Child    male   7.00      4      1
# 58            59         1       2  Child  female   5.00      1      2
# 59            60         0       3  Child    male  11.00      5      2
# ...

# %%
missing_age = pd.isnull(titanic_data['Age'])
titanic_data[missing_age_bool].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
age_female = titanic_data[missing_age_bool]['Sex'] == 'female'
age_male = titanic_data[missing_age_bool]['Sex'] == 'male'

print ('Females:'+ str (age_female.sum()),'Males:'+ str (age_male.sum()))
# Out:
# Females:53 Males:124

# %% [markdown]
# ## Data Exploration and visualization
# To come up with the questions I looked through the titanic dataset and came up with questions that I was curious to know and looked into the relationship between certain variables. I also used visualization by using pie charts, bar charts and tables to show the relationship between the variables.
# I uploaded the titanic data and after doing that I looked for duplicates and checked whether the records where all correctly uploaded. I checked the total amounts of males and females, also created a histogram which depicts the ages. Also checked the mean, standard deviation, maximum and medium basically exploring some descriptive statistics. Also explored the data by calculating the number of missing values and cabin had 687 which was the highest and age was the second highest with 177 missing values.
# There was also a look in the number of survivors and deaths between the males and females which also looked into the classes and gave the totals according to the passenger classes. There are pie charts which show the survivors and deaths between the males and females and there is a bar graph which shows the children which are survivors and non- survivors. There is also a look into how many children there are in the dataset plus how many males and females have missing age values.

# %% [markdown]
# ## Conclusion
# From the results age was not a big deal but the passenger class is important as it affects certain things from happening and could have with survival. There were more deaths in the third class then the others and the males had a large number of deaths then females.
